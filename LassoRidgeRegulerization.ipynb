# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge, Lasso

# %%
dataset = pd.read_csv("data.txt")
dataset
# Out:
#    x    y
# 0   1    2
# 1   2    4
# 2   3    6
# 3   4    8

# %%
df = dataset.copy()
x = df.iloc[ : , :-1]
y = df.iloc[ : , -1 ]
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name:  y , dtype: int64

# %%
plt.scatter(x, y, color='blue', marker='o')
plt.title('Scatter Plot of x vs y')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
l = 0
ridge = Ridge(alpha=1)
ridge.fit(x,y)
ridgeCoef = ridge.coef_
ridgeInter = ridge.intercept_

# %%
xTest = x
yPred = ridge.predict(xTest)
yPred
# Out:
# array([2.5       , 4.16666667, 5.83333333, 7.5       ])

# %%
plt.figure(figsize=(10,5) , dpi = 100)
plt.plot(xTest, yPred , c ='r' , linewidth = 2)
plt.scatter(x,y)
plt.ylim(ymin = 0 , ymax = 9)
plt.xlim(xmin = 0 , xmax = 5)
plt.title('ridge Regression')
plt.show()

# %%
l = 0
lasso = Lasso(alpha=1)
lasso.fit(x,y)
ridgeCoef = lasso.coef_
ridgeInter = lasso.intercept_

# %%
xTest = x
yPred = lasso.predict(xTest)
yPred
# Out:
# array([3.2, 4.4, 5.6, 6.8])

# %%
plt.figure(figsize=(10,5) , dpi = 100)
plt.plot(xTest, yPred , c ='r' , linewidth = 2)
plt.scatter(x,y)
plt.ylim(ymin = 0 , ymax = 9)
plt.xlim(xmin = 0 , xmax = 5)
plt.title('ridge Regression')
plt.show()
